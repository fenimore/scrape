# %%
import sys, requests, os
from bs4 import BeautifulSoup
from termcolor import colored, cprint
import 

# This is where the files are hosted
rooturl= "https://thenounproject.com/term/chess/1"

# Set up Arrays
urls = []
downloadurls = []

# %%
r = requests.get(rooturl)
soup = BeautifulSoup(r.text, 'html.parser')
soup.prettify
# Out:
# <bound method BeautifulSoup.prettify of
# <!DOCTYPE html>
#
# <!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js ie8 oldie" lang="en"> <![endif]-->
# <!--[if IE 9]>    <html class="no-js ie9" lang="en">           <![endif]-->
# <!--[if (gt IE 9)|!(IE)]<!--><html class="no-js" lang="en"> <!--<![endif]-->
# <!--
#
# DDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD.
# DDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD.
# DDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD.
# DDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD.
# DDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD.
# DDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD.
# DDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD.
# DDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD.
# DDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD.
# DDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD.
# DDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD.
# DDDDDDDDDDDNNNNDNDDDDDDDDDDDDDDDDNDDDDDDDDDDNNDDDDDDDDDDNNNNNNNNNNNNNNNNNNDDDDD.
# DDDDDDDDD         'DDDDDDDDDDDDD   NDDDDDDDN  DDDDDDDDDD                  NDDDD.
# DDDDDDN             7DDDDDDDDDD     7NDDDD      DDDDDDDD                  NDDDD.
# DDDDDD                DDDDDDDDD$      NNI      NDDDDDDDD                  NDDDD.
# DDDDD                 NDDDDDDDDDN             DDDDDDDDDD                  NDDDD.
# DDDDD                  DDDDDDDDDDDD         DDDDDDDDDDDD                  NDDDD.
# DDDDD                 DDDDDDDDDDO             NDDDDDDDDD                  NDDDD.
# DDDDDD               DDDDDDDDDD       NDD       DDDDDDDD                  NDDDD.
# DDDDDDD.           .NDDDDDDDDDD     NDDDDDI     DDDDDDDD                  DDDDD.
# DDDDDDDDN        ,DNDDDDDDDDDDDD  INDDDDDDDN   DDDDDDDDD                  DDDDD.
# DDDDDDDDDDDDDDNDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDNDDDNNDNNDNDDNNNNDDDDD.
# DDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD.
# DDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD.
# DDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD.
# DDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD.
# DDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD.
# DDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD.
# DDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD.
# DDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD.
# DDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD.
# DDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD.
# DDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD.
# DDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD.
#
#                                                                 The Noun Project
# -->
# <head>
# <meta charset="utf-8">
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible">
# <title>
#     Chess icons
#     | Noun Project
# </title>
# <meta content="Creating, Sharing and Celebrating the World’s Visual Language." name="description">
# <meta content="NOODP" name="robots">
# <!-- social -->
# <meta content="https://d30y9cdsu7xlg0.cloudfront.net/png/1-200.png" property="og:image"/>
# <meta content="The Noun Project" property="og:title"/>
# <meta content="https://thenounproject.com/term/chess/1/" property="og:url"/>
# <meta content="Check out Trash icon created by INVALID EXPRESSION: icon.uploader.name" property="og:description"/>
# <meta content="The Noun Project" property="og:site_name"/>
# <meta content="website" property="og:type"/>
# <meta content="summary" name="twitter:card">
# <meta content="@nounproject" name="twitter:site">
# <meta content="Trash on The Noun Project" name="twitter:title">
# <meta content="Check out Trash icon created by INVALID EXPRESSION: icon.uploader.name" name="twitter:description">
# <meta content="https://d30y9cdsu7xlg0.cloudfront.net/png/1-200.png" name="twitter:image:src">
# <meta content="https://thenounproject.com/term/chess/1/" name="twitter:domain">
# <!-- facebook meta -->
# <meta content="193479170731565" property="fb:app_id">
# <!-- mobile viewport and icons -->
# <meta content="width=device-width,initial-scale=1" name="viewport">
# <!--     <link rel="apple-touch-icon-precomposed" sizes="144x144" href="/img/touch/apple-touch-icon-144x144-precomposed.png">
#     <link rel="apple-touch-icon-precomposed" sizes="114x114" href="/img/touch/apple-touch-icon-114x114-precomposed.png">
#     <link rel="apple-touch-icon-precomposed" sizes="72x72" href="/img/touch/apple-touch-icon-72x72-precomposed.png">
#     <link rel="apple-touch-icon-precomposed" href="/img/touch/apple-touch-icon-57x57-precomposed.png"> -->
# <script>
#         if (!window.noun) {
#             window.noun = {};
#         }
#         window.noun.pageLoadTime = new Date().getTime();
#     </script>
# <!-- favicon -->
# <link href="//thenounproject.com/static/img/favicon.3c1cab1f6e28.ico" rel="shortcut icon">
# <!-- styles -->
# <link href="//thenounproject.com/static/css/core.f23d217174d9.css" rel="stylesheet">
# <!-- head scripts -->
# <script src="//thenounproject.com/static/components/modernizr/modernizr.custom.97732.6bd07f2cff65.js"></script>
# <script data-user-object='{"is_anonymous": true}' id="user-config" type="text/json"></script>
# <!-- Google Analytics -->
# <script>
#         (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#         (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#         m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#         })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#         ga('create', 'UA-26700829-1', 'auto');
#
#
#
#             ga('set', 'dimension1', 'Anonymous');
#
#
#         ga('send', 'pageview');
#     </script>
# </link></link></meta></meta></meta></meta></meta></meta></meta></meta></meta></meta></meta></meta></head>
# <body class=" term-page " data-authentication="false" data-can-consume="false" data-has-premium="false" id="term-detail">
# <div>
# <!-- ## GLOBAL HEADER -->
# <section class="sticky" id="header">
# <nav class="container row">
# <ul class="global-brand">
# <li id="logo">
# <a class="ui_logo" href="/" title="The Noun Project"><h1 class="visuallyhidden">The Noun Project</h1></a>
# <ul class="ui_personal clearfix">
# <li><a href="/about/">About</a></li>
# <li><a href="/for-mac/">For Mac</a></li>
# <li><a href="http://blog.thenounproject.com" target="_blank">Blog</a></li>
# <li><a href="/accounts/pricing/">Pricing</a></li>
# <li><a href="/creators/">Creators</a></li>
# <li><a href="/developers/">Developers</a></li>
# <li><a href="/jobs/">Jobs</a></li>
# <li><a href="/legal/">Legal</a></li>
# <li><a href="https://thenounproject.zendesk.com/hc/en-us" target="_blank">Help?</a></li>
# </ul>
# </li>
# </ul>
# <ul class="global-language">
# <li class="language drop-link ui_down-triangle-after">
# <a href="#" title="change your language">
#
#                             English
#                         </a>
# </li>
# </ul>
# <ul class="global-user">
# <li><a class="ui_upload" href="/upload/" title="Upload Icons">Upload Icons</a></li>
# <li><a class="ui_desktop" href="/for-mac/" title="Noun Project for Mac">For Mac</a></li>
# <li><a class="ui_dollar-sign-circle-filled" href="/accounts/pricing/" title="Pricing">Pricing</a></li>
# <li><a class="ui_sign-up" href="/accounts/pricing/" title="Sign Up">Sign up</a></li>
# <li><a class="ui_key" href="/accounts/login/" title="Login">Login</a></li>
# </ul>
# <section class="drawer" id="language-drawer"><div class="container">
# <h2>The Noun Project community is working <br/>to translate the site.</h2>
# <h3>Want to help us out? <a href="mailto:translate@thenounproject.com">Become a Translator</a>.</h3>
# <form action="/set_language/" method="POST">
# <input name="csrfmiddlewaretoken" type="hidden" value="A7EI2K3abFL78DOzAgL4jUUpZe3pTpXI"/>
# <ul>
# <li>
# <button name="language" value="ar">العربيّة</button>
# </li>
# <li>
# <button name="language" value="bg">български</button>
# </li>
# <li>
# <button name="language" value="cs">česky</button>
# </li>
# <li>
# <button name="language" value="da">dansk</button>
# </li>
# <li>
# <button name="language" value="de">Deutsch</button>
# </li>
# <li>
# <button name="language" value="el">Ελληνικά</button>
# </li>
# <li>
# <button name="language" value="en">English</button>
# </li>
# <li>
# <button name="language" value="en">English</button>
# </li>
# <li>
# <button name="language" value="en-gb">British English</button>
# </li>
# <li>
# <button name="language" value="es">español</button>
# </li>
# <li>
# <button name="language" value="fr">français</button>
# </li>
# <li>
# <button name="language" value="he">עברית</button>
# </li>
# <li>
# <button name="language" value="it">italiano</button>
# </li>
# <li>
# <button name="language" value="ja">日本語</button>
# </li>
# <li>
# <button name="language" value="ko">한국어</button>
# </li>
# <li>
# <button name="language" value="nl">Nederlands</button>
# </li>
# <li>
# <button name="language" value="no">norsk</button>
# </li>
# <li>
# <button name="language" value="pl">polski</button>
# </li>
# <li>
# <button name="language" value="pt">Português</button>
# </li>
# <li>
# <button name="language" value="pt-br">Português Brasileiro</button>
# </li>
# <li>
# <button name="language" value="ro">Română</button>
# </li>
# <li>
# <button name="language" value="ru">Русский</button>
# </li>
# <li>
# <button name="language" value="sk">slovenský</button>
# </li>
# <li>
# <button name="language" value="sv">svenska</button>
# </li>
# <li>
# <button name="language" value="tr">Türkçe</button>
# </li>
# <li>
# <button name="language" value="uk">Українська</button>
# </li>
# <li>
# <button name="language" value="zh-cn">简体中文</button>
# </li>
# <li>
# <button name="language" value="zh-tw">繁體中文</button>
# </li>
# </ul>
# </form>
# </div></section></nav></section></div>
# </body></html>
#
# <div class="react-component" data-component-name="searchbar">
# <section class="search-bar " id="search">
# <div class="container row">
# <form action="/search/" id="search-form" type="GET">
# <label class="ui_search search-label" for="search-input">
# <input class="search-input" id="search-input" name="q" placeholder="Search" role="search" type="text" value="">
# </input></label>
# </form>
# </div>
# </section>
# </div>
# <div id="main-content">
# <section class="search-result" id="search-icons">
# <div class="react-component" data-component-args='[{"pageContext": "termDetail"}]' data-component-name="iconlist"></div>
# </section>
# <section class="modals">
# <div class="react-component" data-component-name="downloadmodal"></div>
# <div class="react-component" data-component-name="authmodal"></div>
# <div class="react-component" data-component-name="sharemodal"></div>
# </section>
# </div>
# <section class="vcard" id="footer">
# <div class="container row">
# <header>
# <h1 class="organization-name">The Noun Project</h1>
# </header>
# <div class="row">
# <form action="/mailing-list/subscribe/" class="email-signup mailer" id="email-updates" method="post" name="mc-embedded-subscribe-form" novalidate="">
# <input name="csrfmiddlewaretoken" type="hidden" value="A7EI2K3abFL78DOzAgL4jUUpZe3pTpXI"/>
# <input id="EMAIL" name="email" placeholder="Email Address" type="email"/>
# <!-- real people should not fill this in and expect good things - do not remove this or risk form bot signups-->
# <label for="EMAIL">To receive our updates via email</label>
# </form>
# </div>
# <nav class="footer-links row">
# <ul class="columns two">
# <li>About</li>
# <li><a href="/about/">The Project</a></li>
# <li><a href="/for-mac/">For Mac</a></li>
# <li><a href="/team/">Teams</a></li>
# <li><a href="/accounts/pricing/">Pricing</a></li>
# <li><a href="http://api.thenounproject.com">API</a></li>
# </ul>
# <ul class="columns two">
# <li>Contribute</li>
# <li><a href="/iconathon/">Iconathon</a></li>
# <li><a href="/upload/">Upload</a></li>
# </ul>
# <ul class="columns two">
# <li>Community</li>
# <li><a href="/developers/">Developers</a></li>
# <li><a href="/creators/" title="For people who make icons">Creators</a></li>
# <li><a href="http://blog.thenounproject.com" target="_blank">Blog</a></li>
# </ul>
# <ul class="columns two">
# <li>Contact</li>
# <li><a class="email" href="mailto:info@thenounproject.com">Email</a></li>
# <li><a href="http://twitter.com/nounproject" target="_blank">Twitter</a></li>
# <li><a href="http://instagram.com/nounproject" target="_blank">Instagram</a></li>
# <li><a href="https://thenounproject.zendesk.com/hc/en-us" target="_blank">Feedback</a></li>
# <li><a href="/jobs/">Jobs</a></li>
# </ul>
# <ul class="columns two">
# <li>Legal</li>
# <li><a href="/legal/#!terms-of-use">Terms of Use</a></li>
# <li><a href="/legal/#!privacy-policy">Privacy Policy</a></li>
# <li><a href="/legal/#!creator-terms">Creators Terms</a></li>
# <li><a href="https://thenounproject.zendesk.com/hc/en-us" target="_blank">Frequent Questions</a></li>
# </ul>
# <div class="the-deck columns two">
# <a href="http://decknetwork.net/" target="_blank">Ads via the Deck</a>
# <script type="text/javascript">
#                         //<![CDATA[
#                         (function(id) {document.write('<script type="text/javascript" src="' + '//connect.decknetwork.net/deck' + id + '_js.php?' + (new Date().getTime()) + '"></' + 'script>'); })("NP");
#                         //]]>
#                     </script>
# </div>
# </nav>
# </div>
# <footer class="container row">
# <span class="columns four">® 2015 The Noun Project</span>
# <div class="facebook-like-button columns two"><div class="fb-like" data-action="like" data-colorscheme="dark" data-href="//thenounproject.com" data-layout="button" data-share="true" data-show-faces="false"></div></div>
# </footer>
# </section>
# <div class="react-component compatibilitymodal" data-component-name="compatibilitymodal"></div>
#
# <div id="fb-root"></div>
# <form action="/logout/" id="logout-form" method="post"></form>
# <!-- Jquery -->
# <!--[if lt IE 9]><script src="//cdnjs.cloudflare.com/ajax/libs/jquery/1.11.2/jquery.min.js"></script><![endif]-->
# <!--[if IE 9]><!--><script src="//cdnjs.cloudflare.com/ajax/libs/jquery/2.0.3/jquery.min.js"></script><!--<![endif]-->
# <script>
#     (function(jQuery) {
#         'use strict';
#         jQuery || document.write('<script src="//thenounproject.com/static/components/jquery/jquery.min.9d64610879be.js"><\/script>');
#     })(window.jQuery);
# </script>
# <!-- Criteo  -->
# <script async="true" src="//static.criteo.net/js/ld/ld.js" type="text/javascript"></script>
# <script>var csrfCookieName = "csrftoken"</script>
# <script src="/jsi18n/"></script>
# <script src="//thenounproject.com/static/components/vendor.min.3df6aa06f50e.js" type="text/javascript"></script>
# <script src="https://js.stripe.com/v2/" type="text/javascript"></script>
# <script src="//thenounproject.com/static/js/bundle.8e4dfa28b831.js"></script>
# <!-- Adroll  -->
# <script type="text/javascript">
#         adroll_adv_id = "T5F6KIYQVFDTNGER5GICXM";
#         adroll_pix_id = "2DODKSL4LFHW3M5XVOP4RO";
#         (function () {
#         var oldonload = window.onload;
#         window.onload = function(){
#            __adroll_loaded=true;
#            var scr = document.createElement("script");
#            var host = (("https:" == document.location.protocol) ? "https://s.adroll.com" : "http://a.adroll.com");
#            scr.setAttribute('async', 'true');
#            scr.type = "text/javascript";
#            scr.src = host + "/j/roundtrip.js";
#            ((document.getElementsByTagName('head') || [null])[0] ||
#             document.getElementsByTagName('script')[0].parentNode).appendChild(scr);
#            if(oldonload){oldonload()}};
#         }());
#     </script>
# <script type="text/javascript">
# </script>
# <div class="modal share-modal" data-style="" data-type="share">
# <div class="table">
# <div class="table-cell">
# <div class="container row">
# <a class="close-button ui_close" href="#close" id="auth-modal-close" title="Press ESC to close"></a>
# <header>
# <h2>Where to Share?</h2>
# </header>
# <div class="social_links">
# <a class="share-on-facebook ui_facebook" href="https://www.facebook.com/sharer/sharer.php" type="button"></a>
# <a class="share-on-twitter ui_twitter" href="//twitter.com/share" type="button"></a>
# <a class="share-on-tumblr ui_tumblr" href="//www.tumblr.com/share/photo" type="button"></a>
# <a class="ui_pinterest" href="//www.pinterest.com/pin/create/button/" id="share-on-pinterest" type="button"></a>
# </div>
# </div>
# </div>
# </div>
# <div class="core-component" data-component-name="share_modal"></div>
# </div>
#
#
# >

# %%
def get_urls(): # y = limit of pages, x = start index
    urls =[]                     
    x = int(input(" Select beginning range. Enter '1' for the very beginning: \n "))
    y = int(input(" Select the final page to search:\n "))
    op_commence = colored(' Operation commencing', 'green')  
    print(op_commence)
    for z in range(x, y):
        address = rooturl + "/browse/" + str(z)
        r = requests.get(address)
        soup = BeautifulSoup(r.text, 'html.parser')
        # The desktop div links to the various images
        backgrounds = soup.find_all("div", {"class":"desktop"})
        for background in backgrounds:
            link = background.find("a")
            url = rooturl + link["href"]
            urls.append(url)
    return urls
